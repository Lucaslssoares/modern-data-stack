# %%
path = '../data/weather_data.json'
import pandas as pd
import json

# %%
with open(path) as f:
    data = json.load(f)

df = pd.json_normalize(data)
df.head()

# %%
df.info()

# %%
import subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "matplotlib", "seaborn", "sqlalchemy", "psycopg2-binary", "python-dotenv"])
